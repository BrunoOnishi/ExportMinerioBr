# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoOnishi/ExportMinerioBr/blob/master/ExportMinerioBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0d17cff-b887-4a27-af53-67e8a885be72" name="files[]" multiple disabled />
#      <output id="result-e0d17cff-b887-4a27-af53-67e8a885be72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NCM.csv to NCM.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['NCM.csv']),encoding = 'cp860', error_bad_lines=False)
# Out:
# b'Skipping line 8: expected 17 fields, saw 19\nSkipping line 14: expected 17 fields, saw 26\nSkipping line 16: expected 17 fields, saw 23\nSkipping line 17: expected 17 fields, saw 23\nSkipping line 18: expected 17 fields, saw 26\nSkipping line 22: expected 17 fields, saw 20\nSkipping line 26: expected 17 fields, saw 20\nSkipping line 31: expected 17 fields, saw 24\nSkipping line 35: expected 17 fields, saw 23\nSkipping line 36: expected 17 fields, saw 20\nSkipping line 37: expected 17 fields, saw 23\nSkipping line 39: expected 17 fields, saw 20\nSkipping line 41: expected 17 fields, saw 51\nSkipping line 42: expected 17 fields, saw 36\nSkipping line 43: expected 17 fields, saw 24\nSkipping line 55: expected 17 fields, saw 20\nSkipping line 61: expected 17 fields, saw 19\nSkipping line 64: expected 17 fields, saw 20\nSkipping line 65: expected 17 fields, saw 18\nSkipping line 66: expected 17 fields, saw 20\nSkipping line 68: expected 17 fields, saw 35\nSkipping line 70: expected 17 f
# ...

# %%
df2
# Out:
#                    CO_NCM  ...                                         NO_NCM_ING
# 38085910 10 380859   3293  ...   presented in forms or packings exclusively fo...
# 38085921 10 380859   3293  ...                                presented otherwise
# 38085922 10 380859   3293  ...                                presented otherwise
# 38085923 10 380859   3293  ...                                presented otherwise
# 38085929 10 380859   3293  ...                                presented otherwise
# ...                   ...  ...                                                ...
# 85402019 11 854020   3381  ...                                                NaN
# 85402020 11 854020   3381  ...                                          of rays x
# 85402090 11 854020   3381  ...                                               etc.
# 85406090 11 854060   3381  ...                                                NaN
# ...
