# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoOnishi/ExportMinerioBr/blob/master/ExportMinerioBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b73aba5-e561-4f47-8f90-061edda8b5c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b73aba5-e561-4f47-8f90-061edda8b5c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NCM_1.csv to NCM_1 (1).csv

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['NCM_1.csv']),sep=';',encoding = 'cp860', error_bad_lines=False, warn_bad_lines=False)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2
# Out:
#          CO_NCM  ...                                         NO_NCM_ING
# 0      38085910  ...  Other commodities mentioned in Note of subhead...
# 1      38085921  ...  Commodities based on methamidophos (ISO) or mo...
# 2      38085922  ...  Commodities based on endosulfan (ISO), present...
# 3      38085923  ...  Commodities based on alachlor (ISO), presented...
# 4      38085929  ...  Commodities based on other substances, present...
# ...         ...  ...                                                ...
# 12907  85405010  ...  Data/graphic display tubes,black/white,scr<33,...
# 12908  85405020  ...  Data/graphic display tubes,black/white,scr>=33...
# 12909  85406010  ...                               Oth.cathoderay tubes
# 12910  85406090  ...                             Other cathoderay tubes
# 12911  85407100  ...                   Tubes for microwaves, magnetrons
#
# [12912 rows x 14 columns]

# %%
dfminerio=df2[df2['NO_NCM_POR'].str.contains('minerio', na=False)]
dfminerio
# Out:
#         CO_NCM  ... minerio
# 3789  26140010  ...    10.0
# 3790  26140090  ...     7.0
# 3791  26151010  ...    11.0
# 3792  26151020  ...    11.0
# 3793  26151090  ...     7.0
# 3798  26179000  ...     7.0
# 4226  26011290  ...     7.0
# 4228  26020010  ...    55.0
# 4761  26020090  ...     7.0
# 4762  26030010  ...    12.0
# 4763  26030090  ...     7.0
# 4766  26060011  ...    23.0
# 4767  26060012  ...    19.0
# 4768  26060090  ...     7.0
# 4770  26080010  ...    12.0
# 4771  26080090  ...     7.0
# 4773  26100010  ...     9.0
# 4774  26100090  ...     7.0
# 4778  26131010  ...    22.0
# 4779  26131090  ...     7.0
# 4780  26139010  ...    26.0
# 4781  26139090  ...     7.0
# 7134  72031000  ...    49.0
# 9491  84749000  ...   125.0
# 9933  84171090  ...    38.0
#
# [25 rows x 15 columns]
